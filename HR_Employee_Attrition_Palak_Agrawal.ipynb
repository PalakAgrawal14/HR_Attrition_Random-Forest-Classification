# %% [markdown]
# <a href="https://colab.research.google.com/github/PalakAgrawal14/HR_Attrition_Random-Forest-Classification/blob/main/HR_Employee_Attrition_Palak_Agrawal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing pandas library 
import pandas as pd

# %%
HR= pd.read_csv("HR-Employee-Attrition.csv")

# %%
# Head function is used to present the top (defult=5) column of the data
HR.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
# Gives number of rows and columns in the data
HR.shape
# Out:
# (1470, 35)

# %%
# Gives statiscital information 
HR.describe()
# Out:
#                Age    DailyRate  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000  ...              1470.000000           1470.000000
# mean     36.923810   802.485714  ...                 2.187755              4.123129
# std       9.135373   403.509100  ...                 3.222430              3.568136
# min      18.000000   102.000000  ...                 0.000000              0.000000
# 25%      30.000000   465.000000  ...                 0.000000              2.000000
# 50%      36.000000   802.000000  ...                 1.000000              3.000000
# 75%      43.000000  1157.000000  ...                 3.000000              7.000000
# max      60.000000  1499.000000  ...                15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
# To check the null values 
HR.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# counting the Attrition 
attrition_count = pd.DataFrame(HR['Attrition'].value_counts())
attrition_count
# Out:
#      Attrition
# No        1233
# Yes        237

# %%
# Import matplotlib and numpy libraries
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Creating pie chart
plt.pie(attrition_count['Attrition'], labels = ['No','yes'],autopct='%1.2f%%', explode=(0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3c45d569d0>,
# ...
#  [Text(-1.136781068348268, 0.6306574368426737, 'No'),
#   Text(0.961891673217765, -0.5336332157899548, 'yes')],
#  [Text(-0.6995575805220109, 0.38809688421087607, '83.88%'),
#   Text(0.5246681853915082, -0.29107266315815716, '16.12%')])

# %%
HR.drop(['EmployeeCount' , 'EmployeeNumber'] , axis = 1)
# Out:
#       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 33 columns]

# %%
# For creating dummy variables of Attrition Variable
attrition_dummies = pd.get_dummies(HR['Attrition'])
attrition_dummies.head()
# Out:
#    No  Yes
# 0   0    1
# 1   1    0
# 2   0    1
# 3   1    0
# 4   1    0

# %%
#for creating the dummy variable
HR = pd.concat([HR, attrition_dummies] , axis = 1)
HR.head()
# Out:
#    Age Attrition     BusinessTravel  ...  YearsWithCurrManager No  Yes
# 0   41       Yes      Travel_Rarely  ...                     5  0    1
# 1   49        No  Travel_Frequently  ...                     7  1    0
# 2   37       Yes      Travel_Rarely  ...                     0  0    1
# 3   33        No  Travel_Frequently  ...                     0  1    0
# 4   27        No      Travel_Rarely  ...                     2  1    0
#
# [5 rows x 37 columns]

# %%
#for removing the extra column
HR = HR.drop( columns= ['No'] )
HR.head()
# Out:
#    Age Attrition  ... YearsWithCurrManager  Yes
# 0   41       Yes  ...                    5    1
# 1   49        No  ...                    7    0
# 2   37       Yes  ...                    0    1
# 3   33        No  ...                    0    0
# 4   27        No  ...                    2    0
#
# [5 rows x 36 columns]

# %%
# creating barplot using Aender and attrition variable 
sns.barplot(x = 'Gender' , y = 'Yes', data = HR)

# %%
# barplot with department and attrition
sns.barplot(x = 'Department' , y = 'Yes', data = HR)

# %%
#Create a new column at the end of the dataframe that contains the same value 
HR['Age_Years'] = HR['Age']
#Remove the first column called age 
HR = HR.drop('Age', axis = 1)

# %%
HR = HR.drop('Over18', axis = 1)

# %%
HR = HR.drop('StandardHours', axis = 1)

# %%
HR = HR.drop('EmployeeCount', axis = 1)

# %%
HR.head()
# Out:
#    Attrition  BusinessTravel  DailyRate  ...  YearsWithCurrManager  Yes  Age_Years
# 0          1               2        624  ...                     5    1         23
# 1          0               1        113  ...                     7    0         31
# 2          1               2        805  ...                     0    1         19
# 3          0               1        820  ...                     0    0         15
# 4          0               2        312  ...                     2    0          9
#
# [5 rows x 33 columns]

# %%
# visualization of correlation matrix
plt.figure(figsize=(15,15))
sns.heatmap(HR.corr(), annot=True, fmt='.0%')

# %%
for column in HR.columns:
        if HR[column].dtype == np.number:
            continue
        HR[column] = LabelEncoder().fit_transform(HR[column])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.

# %%
#Transform non-numeric columns into numerical columns using sklearn.preprocessing
from sklearn.preprocessing import LabelEncoder
for column in HR.columns:
    if HR[column].dtype==np.number:
        continue
    else:
        HR[column]=LabelEncoder().fit_transform(HR[column])
HR.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   after removing the cwd from sys.path.
#    Attrition  BusinessTravel  DailyRate  ...  YearsWithCurrManager  Yes  Age_Years
# 0          1               2        624  ...                     5    1         23
# 1          0               1        113  ...                     7    0         31
# 2          1               2        805  ...                     0    1         19
# 3          0               1        820  ...                     0    0         15
# 4          0               2        312  ...                     2    0          9
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)

# %%
x  = HR.drop(['Yes'], axis = 1)
y = HR['Yes']

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)
x_train.head()
# Out:
#      Attrition  BusinessTravel  ...  YearsWithCurrManager  Age_Years
# 338          0               2  ...                     2         12
# 363          1               2  ...                     0         15
# 759          0               2  ...                     4         27
# 793          0               2  ...                     2         10
# 581          0               2  ...                     2         12
#
# [5 rows x 35 columns]

# %%
#Split the data into independent 'X' and dependent 'Y' variables
X = HR.iloc[:, 1:HR.shape[1]].values 
Y = HR.iloc[:, 0].values 
HR.head()
# Out:
#    Attrition  BusinessTravel  DailyRate  ...  YearsWithCurrManager  Yes  Age_Years
# 0          1               2        624  ...                     5    1         23
# 1          0               1        113  ...                     7    0         31
# 2          1               2        805  ...                     0    1         19
# 3          0               1        820  ...                     0    0         15
# 4          0               2        312  ...                     2    0          9
#
# [5 rows x 33 columns]

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
#Know the accuracy on the training data set
rf.score(x_train,y_train)
# Out:
# 1.0

# %%
#Confusion Matrix and score of the model on the test data
from sklearn.metrics import confusion_matrix
ConMatrix = confusion_matrix(y_test,rf.predict(x_test))

TN = ConMatrix[0][0]
TP = ConMatrix[1][1]
FN = ConMatrix[1][0]
FP = ConMatrix[0][1]

print(ConMatrix)
print('The model testing accuracy = {}'.format((TP+TN)/(TP+TN+FN+FP)))
# Out:
# [[371   0]
#  [  1  69]]
# The model testing accuracy = 0.9977324263038548

# %%
# Returns the feature importances (Higher value indicates the  feature is more important).
imp = pd.DataFrame({'feature':HR.iloc[:, 1:HR.shape[1]].columns,'importance':np.round(rf.feature_importances_,3)}) 
imp = imp.sort_values('importance',ascending=False).set_index('feature')
imp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-49f619743baf> in <module>()
#       1 # Returns the feature importances (Higher value indicates the  feature is more important).
# ----> 2 imp = pd.DataFrame({'feature':HR.iloc[:, 1:HR.shape[1]].columns,'importance':np.round(rf.feature_importances_,5)})
#       3 imp = imp.sort_values('importance',ascending=False).set_index('feature')
#       4 imp
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ...
